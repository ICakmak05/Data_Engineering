# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
#!pip install sqlalchemy psycopg2-binary

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
query = ''' SELECT 1 as number;'''
pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = ''' SELECT * 
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog'
AND
schemaname != 'information_shema'; '''
pd.read_sql(query, con=engine)
# Out:
#            schemaname                tablename tableowner tablespace  \
# 0              public     yellow_tripdata_2021       root       None
# 1              public   yellow_tripdata_2021_1       root       None
# 2  information_schema  sql_implementation_info       root       None
# 3  information_schema                sql_parts       root       None
# 4  information_schema               sql_sizing       root       None
# 5  information_schema             sql_features       root       None
#
#    hasindexes  hasrules  hastriggers  rowsecurity
# 0       False     False        False        False
# 1       False     False        False        False
# 2       False     False        False        False
# 3       False     False        False        False
# 4       False     False        False        False
# 5       False     False        False        False

# %%
#df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)

# %%
#df = pd.read_csv("https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz", nrows=100)

# %%
df1 = pd.read_csv("taxi+_zone_lookup.csv")

# %%
df1.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df = pd.read_csv("https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-01.csv.gz")

# %%
#df.to_csv("c:/Users/ilkca/DATA_ENG_CAMP/data-engineering-zoomcamp/week_1_basics_n_setup/2_docker_sql/yellow_tripdata_2021-01.csv")

# %%
df.shape
# Out:
# (630918, 20)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.to_sql(name = 'yellow_tripdata_2019', con=engine, index=False)
# Out:
# 918

# %%
query = ''' SELECT * 
FROM yellow_tripdata_2019; '''
pd.read_sql(query, con=engine)
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %% [markdown]
# Question_3
# How many taxi trips were totally made on January 15?

# %%
query = ''' SELECT count(* )
FROM yellow_tripdata_2019 
WHERE lpep_pickup_datetime ::date='2019-01-15 '; '''
pd.read_sql(query, con=engine)
# Out:
#    count
# 0  20689

# %% [markdown]
# Question_4
# Which was the day with the largest trip distance?

# %%
query = ''' SELECT date_trunc('day', lpep_pickup_datetime) as date,
max(trip_distance  ) as dis
FROM yellow_tripdata_2019 
group by date
order by dis desc
limit 2; '''
pd.read_sql(query, con=engine)
# Out:
#         date     dis
# 0 2019-01-15  117.99
# 1 2019-01-18   80.96

# %% [markdown]
# Question_5
# In 2019-01-01 how many trips had 2 and 3 passengers?

# %%
#df.columns

# %%
df.rename(columns={'DOLocationID': 'LocationID'}, inplace=True)

# %%
# Merge DataFrames by Column
df2=pd.merge(df,df1, on='LocationID', how='left')

# %%
#df2.head()

# %%
#df2.lpep_pickup_datetime=df2.lpep_pickup_datetime.dt.date

# %%
#df2.lpep_dropoff_datetime=df2.lpep_dropoff_datetime.dt.date

# %%
#df2.head()

# %%
df2.to_sql(name = 'merge_data1', con=engine, index=False)
# Out:
# 918

# %%
print(pd.io.sql.get_schema(df2, name="merge_data"))
# Out:
# CREATE TABLE "merge_data" (
# "VendorID" INTEGER,
#   "lpep_pickup_datetime" DATE,
#   "lpep_dropoff_datetime" DATE,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" INTEGER,
#   "PULocationID" INTEGER,
#   "LocationID" INTEGER,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" INTEGER,
#   "trip_type" INTEGER,
#   "congestion_surcharge" REAL,
#   "Borough" TEXT,
#   "Zone" TEXT,
#   "service_zone" TEXT
# )

# %%
query = ''' SELECT passenger_count , lpep_pickup_datetime
FROM merge_data1 
WHERE lpep_pickup_datetime ::date= '2019-01-01' and passenger_count = 2
;'''
pd.read_sql(query, con=engine)
# Out:
#       passenger_count lpep_pickup_datetime
# 0                   2  2019-01-01 00:10:16
# 1                   2  2019-01-01 00:27:11
# 2                   2  2019-01-01 00:46:20
# 3                   2  2019-01-01 00:13:48
# 4                   2  2019-01-01 00:40:23
# ...               ...                  ...
# 1277                2  2019-01-01 23:08:38
# 1278                2  2019-01-01 23:33:40
# 1279                2  2019-01-01 23:34:15
# 1280                2  2019-01-01 23:08:14
# 1281                2  2019-01-01 23:42:48
#
# [1282 rows x 2 columns]

# %%
query = ''' SELECT passenger_count , lpep_pickup_datetime
FROM merge_data1 
WHERE lpep_pickup_datetime ::date= '2019-01-01' and passenger_count = 3
;'''
pd.read_sql(query, con=engine)
# Out:
#      passenger_count lpep_pickup_datetime
# 0                  3  2019-01-01 00:08:07
# 1                  3  2019-01-01 00:31:28
# 2                  3  2019-01-01 00:39:51
# 3                  3  2019-01-01 00:35:40
# 4                  3  2019-01-01 00:09:09
# ..               ...                  ...
# 249                3  2019-01-01 22:59:53
# 250                3  2019-01-01 22:15:36
# 251                3  2019-01-01 23:20:47
# 252                3  2019-01-01 23:16:50
# 253                3  2019-01-01 23:34:57
#
# [254 rows x 2 columns]

# %% [markdown]
# Question_6
# For the passengers picked up in the Astoria Zone which was the drop up zone that had the largest tip?

# %%
df2.loc[df2["Zone"]=="Astoria"][["tip_amount", "Borough"]].sort_values(by=['tip_amount'], ascending=False)
# Out:
#         tip_amount Borough
# 610078       62.22  Queens
# 309536       20.00  Queens
# 4014         18.16  Queens
# 480960       15.00  Queens
# 190451       15.00  Queens
# ...            ...     ...
# 328906        0.00  Queens
# 329014        0.00  Queens
# 329205        0.00  Queens
# 304457        0.00  Queens
# 118582       -0.66  Queens
#
# [16580 rows x 2 columns]

# %%
list(df2.Zone.unique())
# Out:
# ['NV',
#  'Clinton Hill',
#  'Prospect Heights',
#  'Bedford',
#  'Woodhaven',
#  'Brooklyn Heights',
#  'Stuyvesant Heights',
#  'Flatbush/Ditmas Park',
#  'Canarsie',
#  'Upper West Side North',
#  'Jackson Heights',
#  'East Flatbush/Farragut',
#  'Ocean Hill',
#  'East Williamsburg',
#  'Sutton Place/Turtle Bay North',
#  'TriBeCa/Civic Center',
#  'Astoria',
#  'Maspeth',
#  'Greenpoint',
#  'East Chelsea',
#  'Crown Heights South',
#  'Woodside',
#  'Steinway',
#  'Park Slope',
#  'Williamsburg (South Side)',
#  'Williamsbridge/Olinville',
#  'Parkchester',
#  'Cobble Hill',
#  'Bay Ridge',
#  'Central Harlem North',
#  'Yorkville East',
#  'Kips Bay',
#  'Bronxdale',
#  'Flatlands',
#  'Downtown Brooklyn/MetroTech',
#  'Brownsville',
#  'East Harlem North',
#  'Long Island City/Queens Plaza',
#  'Upper East Side South',
#  'Long Island City/Hunters Point',
#  'Forest Hills',
#  'Yorkville West',
#  'Crown Heights North',
#  'Bensonhurst East',
#  'Fordham South',
# ...
